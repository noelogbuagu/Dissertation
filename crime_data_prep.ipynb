# %% [markdown]
# # Crime Data

# %% [markdown]
# ## Import libraries

# %%
# import libraries
import pandas as pd
import geopandas as gpd
from shapely.geometry import shape
import requests
import warnings
from datetime import datetime, timedelta
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Prepare Data

# %% [markdown]
# ### Import

# %%
# Define base URL for the Police API
endpoint = "https://data.police.uk/api/crimes-street/all-crime"

# Define a large polygon that covers Merseyside County and its cities
# This is an approximate bounding box that will be divided into smaller sub-polygons
large_polygon = [
    [53.6967, -3.2603],  # Northwest corner (near Southport)
    [53.3700, -3.2603],  # Southwest corner (near Wirral)
    [53.3700, -2.5500],  # Southeast corner (near Warrington)
    [53.6967, -2.5500],  # Northeast corner (near Wigan)
    [53.6967, -3.2603],  # Closing the polygon back at the Northwest corner
]

# Function to divide the large polygon into sub-polygons
def create_sub_polygons(large_polygon, divisions=2):
    # Split the large polygon into smaller sub-polygons
    # Assuming a rectangular shape for simplicity
    lat_min, lat_max = min(pt[0] for pt in large_polygon), max(
        pt[0] for pt in large_polygon)
    lng_min, lng_max = min(pt[1] for pt in large_polygon), max(
        pt[1] for pt in large_polygon)

    lat_step = (lat_max - lat_min) / divisions
    lng_step = (lng_max - lng_min) / divisions

    sub_polygons = []
    for i in range(divisions):
        for j in range(divisions):
            sub_polygon = [
                [lat_min + i * lat_step, lng_min + j * lng_step],
                [lat_min + i * lat_step, lng_min + (j + 1) * lng_step],
                [lat_min + (i + 1) * lat_step, lng_min + (j + 1) * lng_step],
                [lat_min + (i + 1) * lat_step, lng_min + j * lng_step],
                [lat_min + i * lat_step, lng_min + j * lng_step],
            ]
            sub_polygons.append(sub_polygon)

    return sub_polygons


# Divide the large polygon into smaller sub-polygons
sub_polygons = create_sub_polygons(
    large_polygon, divisions=3)  # Adjust divisions as needed

# Date range from June 2021 to the current date
start_date = datetime(2021, 6, 1)
end_date = datetime.now()

# Initialize an empty list to store the crime data
all_crimes = []

# Loop through each sub-polygon and month in the date range to collect data
for sub_polygon in sub_polygons:
    polygon_str = ":".join([f"{lat},{lng}" for lat, lng in sub_polygon])

    current_date = start_date
    while current_date <= end_date:
        date_str = current_date.strftime("%Y-%m")

        # Make the API call using the sub-polygon
        api_url = f"{endpoint}?date={date_str}&poly={polygon_str}"

        # Send the request to the API
        response = requests.get(api_url)

        # Check if the request was successful
        if response.status_code == 200:
            crimes = response.json()
            all_crimes.extend(crimes)
            print(
                f"Retrieved {len(crimes)} crime records for {date_str} in sub-polygon")
        elif response.status_code == 503:
            print(
                f"Request exceeded limit for {date_str} in sub-polygon. Consider further subdivision or reducing the date range.")
        else:
            print(
                f"Failed to retrieve data for {date_str}: {response.status_code}")

        # Move to the next month
        current_date += timedelta(days=31)
        # Ensure we start at the beginning of the next month
        current_date = current_date.replace(day=1)

# Convert the collected data to a DataFrame
crimes_df = pd.DataFrame(all_crimes)
# Out:
# Retrieved 2129 crime records for 2021-06 in sub-polygon
# Retrieved 2154 crime records for 2021-07 in sub-polygon
# Retrieved 2011 crime records for 2021-08 in sub-polygon
# Retrieved 2016 crime records for 2021-09 in sub-polygon
# Retrieved 1997 crime records for 2021-10 in sub-polygon
# Retrieved 2071 crime records for 2021-11 in sub-polygon
# Retrieved 1835 crime records for 2021-12 in sub-polygon
# Retrieved 1903 crime records for 2022-01 in sub-polygon
# Retrieved 1830 crime records for 2022-02 in sub-polygon
# Retrieved 2129 crime records for 2022-03 in sub-polygon
# Retrieved 1926 crime records for 2022-04 in sub-polygon
# Retrieved 2161 crime records for 2022-05 in sub-polygon
# Retrieved 2054 crime records for 2022-06 in sub-polygon
# Retrieved 1971 crime records for 2022-07 in sub-polygon
# Retrieved 2164 crime records for 2022-08 in sub-polygon
# Retrieved 1916 crime records for 2022-09 in sub-polygon
# Retrieved 1972 crime records for 2022-10 in sub-polygon
# Retrieved 1954 crime records for 2022-11 in sub-polygon
# Retrieved 1578 crime records for 2022-12 in sub-polygon
# Retrieved 1723 crime records for 2023-01 in sub-polygon
# Retrieved 1793 crime records for 2023-02 in sub-polygon
# Retrieved 1888 crime records for 2023-03 in sub-polygon
# Retrieved 1797 crime records for 2023-04 in sub-polygon
# Retrieved 2035 crime records for 2023-05 in sub-polygon
# Retrieved 1870 crime records for 2023-06 in sub-polygon
# Retrieved 1645 crime records for 2023-07 in sub-polygon
# Retrieved 1594 crime records for 2023-08 in sub-polygon
# Retrieved 1682 crime records for 2023-09 in sub-polygon
# Retrieved 1453 crime records for 2023-10 in sub-polygon
# Retrieved 1316 crime records for 2023-11 in sub-polygon
# Retrieved 1330 crime records for 2023-12 in sub-polygon
# Retrieved 1451 crime records for 2024-01 in sub-polygon
# Retrieved 1328 crime records for 2024-02 in sub-polygon
# Retrieved 1423 crime records for 2024-03 in sub-polygon
# Retrieved 1477 crime records for 2024-04 in sub-polygon
# Retrieved 1607 crime records for 2024-05 in sub-polygon
# Retrieved 0 crime records for 2024-06 in sub-polygon
# Failed to retrieve data for 2024-07: 404
# Failed to retrieve data for 2024-08: 404
# Retrieved 8872 crime records for 2021-06 in sub-polygon
# Retrieved 9197 crime records for 2021-07 in sub-polygon
# Retrieved 8304 crime records for 2021-08 in sub-polygon
# Retrieved 8512 crime records for 2021-09 in sub-polygon
# Retrieved 9345 crime records for 2021-10 in sub-polygon
# Retrieved 8814 crime records for 2021-11 in sub-polygon
# Retrieved 7677 crime records for 2021-12 in sub-polygon
# Retrieved 8324 crime records for 2022-01 in sub-polygon
# Retrieved 7674 crime records for 2022-02 in sub-polygon
# Retrieved 9007 crime records for 2022-03 in sub-polygon
# Retrieved 8381 crime records for 2022-04 in sub-polygon
# Retrieved 9465 crime records for 2022-05 in sub-polygon
# Retrieved 8640 crime records for 2022-06 in sub-polygon
# Retrieved 8611 crime records for 2022-07 in sub-polygon
# Retrieved 8964 crime records for 2022-08 in sub-polygon
# Retrieved 8498 crime records for 2022-09 in sub-polygon
# Retrieved 8931 crime records for 2022-10 in sub-polygon
# Retrieved 8631 crime records for 2022-11 in sub-polygon
# Retrieved 7391 crime records for 2022-12 in sub-polygon
# Retrieved 7877 crime records for 2023-01 in sub-polygon
# Retrieved 7756 crime records for 2023-02 in sub-polygon
# Retrieved 8160 crime records for 2023-03 in sub-polygon
# Retrieved 7892 crime records for 2023-04 in sub-polygon
# Retrieved 8399 crime records for 2023-05 in sub-polygon
# Retrieved 8232 crime records for 2023-06 in sub-polygon
# Retrieved 7591 crime records for 2023-07 in sub-polygon
# Retrieved 7633 crime records for 2023-08 in sub-polygon
# Retrieved 7455 crime records for 2023-09 in sub-polygon
# Retrieved 7626 crime records for 2023-10 in sub-polygon
# Retrieved 7118 crime records for 2023-11 in sub-polygon
# Retrieved 6794 crime records for 2023-12 in sub-polygon
# Retrieved 6848 crime records for 2024-01 in sub-polygon
# Retrieved 6523 crime records for 2024-02 in sub-polygon
# Retrieved 7196 crime records for 2024-03 in sub-polygon
# Retrieved 7099 crime records for 2024-04 in sub-polygon
# Retrieved 7780 crime records for 2024-05 in sub-polygon
# Retrieved 0 crime records for 2024-06 in sub-polygon
# Failed to retrieve data for 2024-07: 404
# Failed to retrieve data for 2024-08: 404
# Retrieved 3472 crime records for 2021-06 in sub-polygon
# Retrieved 3720 crime records for 2021-07 in sub-polygon
# Retrieved 3372 crime records for 2021-08 in sub-polygon
# Retrieved 3556 crime records for 2021-09 in sub-polygon
# Retrieved 3874 crime records for 2021-10 in sub-polygon
# Retrieved 3293 crime records for 2021-11 in sub-polygon
# Retrieved 3141 crime records for 2021-12 in sub-polygon
# Retrieved 3654 crime records for 2022-01 in sub-polygon
# Retrieved 3171 crime records for 2022-02 in sub-polygon
# Retrieved 3640 crime records for 2022-03 in sub-polygon
# Retrieved 3542 crime records for 2022-04 in sub-polygon
# Retrieved 3664 crime records for 2022-05 in sub-polygon
# Retrieved 3575 crime records for 2022-06 in sub-polygon
# Retrieved 3437 crime records for 2022-07 in sub-polygon
# Retrieved 3484 crime records for 2022-08 in sub-polygon
# Retrieved 3332 crime records for 2022-09 in sub-polygon
# Retrieved 3490 crime records for 2022-10 in sub-polygon
# Retrieved 3268 crime records for 2022-11 in sub-polygon
# Retrieved 2874 crime records for 2022-12 in sub-polygon
# Retrieved 3104 crime records for 2023-01 in sub-polygon
# Retrieved 3230 crime records for 2023-02 in sub-polygon
# Retrieved 3388 crime records for 2023-03 in sub-polygon
# Retrieved 3368 crime records for 2023-04 in sub-polygon
# Retrieved 3527 crime records for 2023-05 in sub-polygon
# Retrieved 3323 crime records for 2023-06 in sub-polygon
# Retrieved 3003 crime records for 2023-07 in sub-polygon
# Retrieved 2864 crime records for 2023-08 in sub-polygon
# Retrieved 2850 crime records for 2023-09 in sub-polygon
# Retrieved 2856 crime records for 2023-10 in sub-polygon
# Retrieved 2749 crime records for 2023-11 in sub-polygon
# Retrieved 2502 crime records for 2023-12 in sub-polygon
# Retrieved 2668 crime records for 2024-01 in sub-polygon
# Retrieved 2698 crime records for 2024-02 in sub-polygon
# Retrieved 2763 crime records for 2024-03 in sub-polygon
# Retrieved 2822 crime records for 2024-04 in sub-polygon
# Retrieved 1141 crime records for 2022-08 in sub-polygon
# Retrieved 1053 crime records for 2022-09 in sub-polygon
# Retrieved 1080 crime records for 2022-10 in sub-polygon
# Retrieved 1002 crime records for 2022-11 in sub-polygon
# Retrieved 919 crime records for 2022-12 in sub-polygon
# Retrieved 1014 crime records for 2023-01 in sub-polygon
# Retrieved 969 crime records for 2023-02 in sub-polygon
# Retrieved 1070 crime records for 2023-03 in sub-polygon
# Retrieved 1080 crime records for 2023-04 in sub-polygon
# Retrieved 1086 crime records for 2023-05 in sub-polygon
# Retrieved 1031 crime records for 2023-06 in sub-polygon
# Retrieved 1003 crime records for 2023-07 in sub-polygon
# Retrieved 1102 crime records for 2023-08 in sub-polygon
# Retrieved 1000 crime records for 2023-09 in sub-polygon
# Retrieved 1005 crime records for 2023-10 in sub-polygon
# Retrieved 967 crime records for 2023-11 in sub-polygon
# Retrieved 778 crime records for 2023-12 in sub-polygon
# Retrieved 850 crime records for 2024-01 in sub-polygon
# Retrieved 855 crime records for 2024-02 in sub-polygon
# Retrieved 879 crime records for 2024-03 in sub-polygon
# Retrieved 942 crime records for 2024-04 in sub-polygon
# Retrieved 976 crime records for 2024-05 in sub-polygon
# Retrieved 0 crime records for 2024-06 in sub-polygon
# Failed to retrieve data for 2024-07: 404
# Failed to retrieve data for 2024-08: 404
# Retrieved 406 crime records for 2021-06 in sub-polygon
# Retrieved 375 crime records for 2021-07 in sub-polygon
# Retrieved 356 crime records for 2021-08 in sub-polygon
# Retrieved 354 crime records for 2021-09 in sub-polygon
# Retrieved 405 crime records for 2021-10 in sub-polygon
# Retrieved 402 crime records for 2021-11 in sub-polygon
# Retrieved 340 crime records for 2021-12 in sub-polygon
# Retrieved 404 crime records for 2022-01 in sub-polygon
# Retrieved 386 crime records for 2022-02 in sub-polygon
# Retrieved 468 crime records for 2022-03 in sub-polygon
# Retrieved 423 crime records for 2022-04 in sub-polygon
# Retrieved 438 crime records for 2022-05 in sub-polygon
# Retrieved 397 crime records for 2022-06 in sub-polygon
# Retrieved 427 crime records for 2022-07 in sub-polygon
# Retrieved 416 crime records for 2022-08 in sub-polygon
# Retrieved 396 crime records for 2022-09 in sub-polygon
# Retrieved 388 crime records for 2022-10 in sub-polygon
# Retrieved 384 crime records for 2022-11 in sub-polygon
# Retrieved 319 crime records for 2022-12 in sub-polygon
# Retrieved 388 crime records for 2023-01 in sub-polygon
# Retrieved 405 crime records for 2023-02 in sub-polygon
# Retrieved 417 crime records for 2023-03 in sub-polygon
# Retrieved 364 crime records for 2023-04 in sub-polygon
# Retrieved 354 crime records for 2023-05 in sub-polygon
# Retrieved 365 crime records for 2023-06 in sub-polygon
# Retrieved 422 crime records for 2023-07 in sub-polygon
# Retrieved 417 crime records for 2023-08 in sub-polygon
# Retrieved 365 crime records for 2023-09 in sub-polygon
# Retrieved 375 crime records for 2023-10 in sub-polygon
# Retrieved 373 crime records for 2023-11 in sub-polygon
# Retrieved 374 crime records for 2023-12 in sub-polygon
# Retrieved 438 crime records for 2024-01 in sub-polygon
# Retrieved 410 crime records for 2024-02 in sub-polygon
# Retrieved 366 crime records for 2024-03 in sub-polygon
# Retrieved 368 crime records for 2024-04 in sub-polygon
# Retrieved 441 crime records for 2024-05 in sub-polygon
# Retrieved 0 crime records for 2024-06 in sub-polygon
# Failed to retrieve data for 2024-07: 404
# Failed to retrieve data for 2024-08: 404
# Retrieved 114 crime records for 2021-06 in sub-polygon
# Retrieved 107 crime records for 2021-07 in sub-polygon
# Retrieved 111 crime records for 2021-08 in sub-polygon
# Retrieved 96 crime records for 2021-09 in sub-polygon
# Retrieved 89 crime records for 2021-10 in sub-polygon
# Retrieved 69 crime records for 2021-11 in sub-polygon
# Retrieved 65 crime records for 2021-12 in sub-polygon
# Retrieved 89 crime records for 2022-01 in sub-polygon
# Retrieved 73 crime records for 2022-02 in sub-polygon
# Retrieved 103 crime records for 2022-03 in sub-polygon
# Retrieved 95 crime records for 2022-04 in sub-polygon
# Retrieved 103 crime records for 2022-05 in sub-polygon
# Retrieved 73 crime records for 2022-06 in sub-polygon
# Retrieved 103 crime records for 2022-07 in sub-polygon
# Retrieved 98 crime records for 2022-08 in sub-polygon
# Retrieved 76 crime records for 2022-09 in sub-polygon
# Retrieved 60 crime records for 2022-10 in sub-polygon
# Retrieved 57 crime records for 2022-11 in sub-polygon
# Retrieved 72 crime records for 2022-12 in sub-polygon
# Retrieved 72 crime records for 2023-01 in sub-polygon
# Retrieved 84 crime records for 2023-02 in sub-polygon
# Retrieved 66 crime records for 2023-03 in sub-polygon
# Retrieved 90 crime records for 2023-04 in sub-polygon
# Retrieved 109 crime records for 2023-05 in sub-polygon
# Retrieved 89 crime records for 2023-06 in sub-polygon
# Retrieved 69 crime records for 2023-07 in sub-polygon
# Retrieved 77 crime records for 2023-08 in sub-polygon
# Retrieved 85 crime records for 2023-09 in sub-polygon
# Retrieved 59 crime records for 2023-10 in sub-polygon
# Retrieved 69 crime records for 2023-11 in sub-polygon
# Retrieved 56 crime records for 2023-12 in sub-polygon
# Retrieved 47 crime records for 2024-01 in sub-polygon
# Retrieved 55 crime records for 2024-02 in sub-polygon
# Retrieved 55 crime records for 2024-03 in sub-polygon
# Retrieved 74 crime records for 2024-04 in sub-polygon
# Retrieved 64 crime records for 2024-05 in sub-polygon
# Retrieved 0 crime records for 2024-06 in sub-polygon
# Failed to retrieve data for 2024-07: 404
# Failed to retrieve data for 2024-08: 404
# Retrieved 882 crime records for 2021-06 in sub-polygon
# Retrieved 991 crime records for 2021-07 in sub-polygon
# Retrieved 964 crime records for 2021-08 in sub-polygon
# Retrieved 945 crime records for 2021-09 in sub-polygon
# Retrieved 808 crime records for 2021-10 in sub-polygon
# Retrieved 841 crime records for 2021-11 in sub-polygon
# Retrieved 697 crime records for 2021-12 in sub-polygon
# Retrieved 814 crime records for 2022-01 in sub-polygon
# Retrieved 791 crime records for 2022-02 in sub-polygon
# Retrieved 815 crime records for 2022-03 in sub-polygon
# Retrieved 1064 crime records for 2023-09 in sub-polygon
# Retrieved 1155 crime records for 2023-10 in sub-polygon
# Retrieved 1080 crime records for 2023-11 in sub-polygon
# Retrieved 989 crime records for 2023-12 in sub-polygon
# Retrieved 940 crime records for 2024-01 in sub-polygon
# Retrieved 849 crime records for 2024-02 in sub-polygon
# Retrieved 1060 crime records for 2024-03 in sub-polygon
# Retrieved 947 crime records for 2024-04 in sub-polygon
# Retrieved 1015 crime records for 2024-05 in sub-polygon
# Retrieved 0 crime records for 2024-06 in sub-polygon
# Failed to retrieve data for 2024-07: 404
# Failed to retrieve data for 2024-08: 404
# Crime data saved to 'merseyside_crime_data_sub_polygons.csv'

# %%
import pandas as pd

# Assuming crimes_df is already populated and contains the necessary data

# Extract latitude and longitude from the 'location' dictionary
crimes_df['latitude'] = crimes_df['location'].apply(lambda x: x['latitude'])
crimes_df['longitude'] = crimes_df['location'].apply(lambda x: x['longitude'])

# Extract the 'id' and 'name' from the 'street' dictionary within the 'location' dictionary
crimes_df['street_id'] = crimes_df['location'].apply(
    lambda x: x['street']['id'])
crimes_df['street_name'] = crimes_df['location'].apply(
    lambda x: x['street']['name'])

# Extract 'category' and 'date' from the 'outcome_status' dictionary
crimes_df['outcome_category'] = crimes_df['outcome_status'].apply(
    lambda x: x['category'] if pd.notnull(x) else None)
crimes_df['outcome_date'] = crimes_df['outcome_status'].apply(
    lambda x: x['date'] if pd.notnull(x) else None)

# Optionally, drop the original 'location' and 'outcome_status' columns if they're no longer needed
crimes_df.drop(columns=['location', 'outcome_status'], inplace=True)

# %%
crimes_df.head()
# Out:
#                 category location_type context persistent_id        id  \
# 0  anti-social-behaviour         Force                        93582823
# 1  anti-social-behaviour         Force                        93576584
# 2  anti-social-behaviour         Force                        93576686
# 3  anti-social-behaviour         Force                        93587118
# 4  anti-social-behaviour         Force                        93579417
#
#   location_subtype    month   latitude  longitude  street_id  \
# 0                   2021-06  53.386978  -3.082421     908033
# 1                   2021-06  53.392841  -3.031395     910714
# 2                   2021-06  53.372197  -3.185789     907754
# 3                   2021-06  53.420545  -3.068271     915238
# 4                   2021-06  53.421259  -3.033031     915107
#
#                     street_name outcome_category outcome_date
# 0    On or near Coniston Avenue             None         None
# 1       On or near Hilton Close             None         None
# 2        On or near Supermarket             None         None
# 3  On or near Gainsborough Road             None         None
# 4     On or near Trafalgar Road             None         None

# %%
# # Extract only relevant columns for crime location and category
crime_relevant_df = crimes_df[['month', 'category', 'latitude', 'longitude']]

# %%
crime_relevant_df.head()
# Out:
#      month               category   latitude  longitude
# 0  2021-06  anti-social-behaviour  53.386978  -3.082421
# 1  2021-06  anti-social-behaviour  53.392841  -3.031395
# 2  2021-06  anti-social-behaviour  53.372197  -3.185789
# 3  2021-06  anti-social-behaviour  53.420545  -3.068271
# 4  2021-06  anti-social-behaviour  53.421259  -3.033031

# %%
# Save the DataFrame to a CSV file
crime_relevant_df.to_csv('clean_data/clean_crime_data.csv', index=False)

# %% [markdown]
# - calculate crime density
# - best radius for crime density
